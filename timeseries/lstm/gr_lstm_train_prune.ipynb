# %%
import torch
import torch.nn as nn
import torch_pruning as tp
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
import os
import numpy as np
import os

# %% [markdown]
# # Define the LSTM model class as provided

# %%
class LSTMmodel(nn.Module):
    def __init__(self, input_size: int, hidden_size: int, num_layers: int, output_size: int, dropout_rate: float = 0.5):
        super(LSTMmodel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.model_type = 'LSTM'

        # Define LSTM layer with dropout
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_rate)

        # Define a fully connected layer to map LSTM output to the target
        self.fc = nn.Linear(hidden_size, output_size)

        # Define a dropout layer before the fully connected layer
        self.dropout = nn.Dropout(dropout_rate)

        # Initialize weights
        self.init_weights()

    def init_weights(self) -> None:
        for name, param in self.lstm.named_parameters():
            if 'weight_ih' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param.data)
            elif 'bias' in name:
                nn.init.constant_(param.data, 0)
        nn.init.xavier_uniform_(self.fc.weight)
        nn.init.constant_(self.fc.bias, 0)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = out[:, -1, :]
        out = self.dropout(out)
        out = self.fc(out)
        return out

# %% [markdown]
# # Dataset class for the Appliances Energy Prediction dataset

# %%
class EnergyDataset(Dataset):
    def __init__(self, data, seq_len, feature_cols, target_col='Appliances'):
        self.seq_len = seq_len
        self.feature_cols = feature_cols
        self.target_col = target_col
        self.scaler = MinMaxScaler()
        # Scale all data together
        self.data_scaled = self.scaler.fit_transform(data[feature_cols + [target_col]])

    def __len__(self):
        return len(self.data_scaled) - self.seq_len

    def __getitem__(self, idx):
        sequence = self.data_scaled[idx:idx + self.seq_len, :-1]  # Exclude target from sequence
        label = self.data_scaled[idx + self.seq_len, -1]  # Target is the last column
        return torch.tensor(sequence, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# %% [markdown]
# # Function to load and prepare data

# %%
def get_data_loaders(data_path, seq_len=24, batch_size=32, feature_cols=None, target_col='Appliances'):
    # Load the dataset
    data = pd.read_csv(data_path)

    # Default feature columns (all except 'date', 'Appliances', 'lights')
    if feature_cols is None:
        feature_cols = [
            'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5',
            'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out',
            'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility', 'Tdewpoint'
        ]

    # Select relevant columns
    data = data[feature_cols + [target_col]]

    # Drop rows with missing values
    data = data.dropna()

    # Create dataset
    dataset = EnergyDataset(data, seq_len, feature_cols, target_col)

    # Split into train and test sets
    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %% [markdown]
# # Training function

# %%
def train_model(model, train_loader, criterion, optimizer, device, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(train_loader):.4f}")

# %% [markdown]
# # Pruning function with structured pruning

# %%
def prune_model(model, example_input, train_loader, strategy, pruning_ratio=0.5, iterative_steps=5):
    pruner = strategy['pruner'](
        model,
        example_input,
        importance=strategy['importance'],
        iterative_steps=iterative_steps,
        ch_sparsity=pruning_ratio,
        root_module_types=[nn.LSTM],
        ignored_layers=[model.fc],
    )

    for i in range(iterative_steps):
        if isinstance(strategy['importance'], tp.importance.TaylorImportance):
            model.train()
            model.zero_grad()
            inputs, labels = next(iter(train_loader))
            inputs, labels = inputs.to(example_input.device), labels.to(example_input.device)
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels)
            loss.backward()
        pruner.step()
    return model

# %% [markdown]
# # Evaluation function (MSE for regression)

# %%
def evaluate_model(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    total_mae = 0.0
    predictions, targets = [], []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels)
            total_loss += loss.item()
            total_mae += torch.mean(torch.abs(outputs.squeeze() - labels)).item()
            predictions.extend(outputs.squeeze().cpu().numpy())
            targets.extend(labels.cpu().numpy())

    mse = total_loss / len(test_loader)
    mae = total_mae / len(test_loader)
    r2 = 1 - (sum((t - p) ** 2 for t, p in zip(targets, predictions)) / sum((t - np.mean(targets)) ** 2 for t in targets))

    print(f"MSE: {mse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}")
    return mse, mae, r2

# %% [markdown]
# # Save model

# %%
def save_model(model, path, example_input):
    torch.save(model.state_dict(), path)
    onnx_path = path.replace('.pth', '.onnx')
    torch.onnx.export(
        model,
        example_input,
        onnx_path,
        export_params=True,
        opset_version=11,
        do_constant_folding=True,
        input_names=['input'],
        output_names=['output'],
        dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
    )
    print(f"Model saved to {path} and {onnx_path}")

# %% [markdown]
# # Main function

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Configuration dictionary
    config = {
        'strategies': {
            'magnitude': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.MagnitudeImportance(p=2),
            },
            'bn_scale': {
                'pruner': tp.pruner.BNScalePruner,
                'importance': tp.importance.BNScaleImportance(),
            },
            'group_norm': {
                'pruner': tp.pruner.GroupNormPruner,
                'importance': tp.importance.GroupMagnitudeImportance(p=1),
            },
            'random': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.RandomImportance(),
            },
            'Taylor': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.TaylorImportance()
            },
            'Hessian': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.GroupHessianImportance()
            },
            'lamp': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.LAMPImportance(p=2)
            },
            'geometry': {
                'pruner': tp.pruner.MagnitudePruner,
                'importance': tp.importance.FPGMImportance()
            },
        },
        'target_macs_sparsity': 0.5,
        'train_epochs': 10,
        'fine_tune_epochs': 20,
        'data_dir': './data',
        'output_dir': './output/strategies',
        'iterative_steps': 5,
    }

    # Initialize model parameters
    input_size = 24  # Number of features
    hidden_size = 64
    num_layers = 1
    output_size = 1
    dropout_rate = 0.5
    seq_len = 24
    batch_size = 32
    data_path = os.path.join(config['data_dir'], 'energydata_complete.csv')

    # Initialize model, criterion, and optimizer
    model = LSTMmodel(input_size, hidden_size, num_layers, output_size, dropout_rate).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Load data
    train_loader, test_loader = get_data_loaders(data_path, seq_len=seq_len, batch_size=batch_size)

    # Train initial model
    print("Training initial model...")
    train_model(model, train_loader, criterion, optimizer, device, num_epochs=config['train_epochs'])

    # Evaluate initial model
    print("Evaluating initial model...")
    mse, mae, r2 = evaluate_model(model, test_loader, criterion, device)

    # Save initial model
    initial_model_path = os.path.join(config['output_dir'], 'lstm_initial.pth')
    example_input = torch.randn(1, seq_len, input_size).to(device)
    save_model(model, initial_model_path, example_input)

    # Pruning loop for each strategy
    for strategy_name, strategy in config['strategies'].items():
        print(f"\nPruning with strategy: {strategy_name}")
        model_copy = LSTMmodel(input_size, hidden_size, num_layers, output_size, dropout_rate).to(device)
        model_copy.load_state_dict(torch.load(initial_model_path))

        # Prune the model
        pruned_model = prune_model(model_copy, example_input, train_loader, strategy, iterative_steps=config['iterative_steps'])

        # Fine-tune the pruned model
        optimizer = torch.optim.Adam(pruned_model.parameters(), lr=0.001)
        train_model(pruned_model, train_loader, criterion, optimizer, device, num_epochs=config['fine_tune_epochs'])

        # Evaluate pruned model
        print(f"Evaluating pruned model with {strategy_name}...")
        mse, mae, r2 = evaluate_model(pruned_model, test_loader, criterion, device)

        # Save pruned and fine-tuned model
        pruned_model_path = os.path.join(config['output_dir'], f'lstm_{strategy_name}_pruned.pth')
        save_model(pruned_model, pruned_model_path, example_input)

    print("All pruning strategies completed.")

# %% [markdown]
# # Run the main function

# %%
if __name__ == "__main__":
    main()
# Out:
# /home/muis/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn(
# Training initial model...
# Epoch 1/10, Loss: 0.0103
# Epoch 2/10, Loss: 0.0087
# Epoch 3/10, Loss: 0.0085
# Epoch 4/10, Loss: 0.0084
# Epoch 5/10, Loss: 0.0084
# Epoch 6/10, Loss: 0.0083
# Epoch 7/10, Loss: 0.0082
# Epoch 8/10, Loss: 0.0081
# Epoch 9/10, Loss: 0.0080
# Epoch 10/10, Loss: 0.0079
# Evaluating initial model...
# MSE: 0.0081, MAE: 0.0497, R²: 0.1392
# Model saved to ./output/strategies/lstm_initial.pth and ./output/strategies/lstm_initial.onnx
#
# Pruning with strategy: magnitude
# /home/muis/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch/onnx/symbolic_opset9.py:4277: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# /home/muis/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn(
# /home/muis/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/pruner/algorithms/base_pruner.py:87: UserWarning: ch_sparsity is deprecated in v1.3.0. Please use pruning_ratio.
#   warnings.warn(
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [25,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [28,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [26,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [27,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[26], line 86, in main()
#      83 model_copy.load_state_dict(torch.load(initial_model_path))
#      85 # Prune the model
# ---> 86 pruned_model = prune_model(model_copy, example_input, train_loader, strategy, iterative_steps=config['iterative_steps'])
#      88 # Fine-tune the pruned model
#      89 optimizer = torch.optim.Adam(pruned_model.parameters(), lr=0.001)
#
# Cell In[20], line 21, in prune_model(model, example_input, train_loader, strategy, pruning_ratio, iterative_steps)
#      19         loss = criterion(outputs.squeeze(), labels)
#      20         loss.backward()
# ---> 21     pruner.step()
#      22 return model
#
# File ~/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/pruner/algorithms/base_pruner.py:270, in BasePruner.step(self, interactive)
#     268 else:
#     269     for group in self._prune():
# --> 270         group.prune()
#
# File ~/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/dependency.py:199, in Group.prune(self, idxs, record_history)
#     197             self._DG.module2node[pruned_parameter].module = pruned_parameter
#     198         else: # in most cases, we can directly prune the module
# --> 199             dep(idxs)
#     201 if record_history: # record the pruning history
#     202     root_module, pruning_fn, root_pruning_idx = self[0][0].target.module, self[0][0].trigger, self[0][1]
#
# File ~/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/dependency.py:110, in Dependency.__call__(self, idxs)
#     108 if len(idxs)>0 and isinstance(idxs[0], _helpers._HybridIndex):
#     109     idxs = _helpers.to_plain_idxs(idxs) # hybrid indices include root indices. We need to remove them and only pass the plain indices to the handler
# --> 110 result = self.handler(self.target.module, idxs)
#     111 return result
#
# File ~/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/pruner/function.py:378, in LSTMPruner.prune_out_channels(self, layer, idxs)
#     374     setattr(layer, 'bias_hh_l0'+pf, self._prune_parameter_and_grad(
#     375         getattr(layer, 'bias_hh_l0'+pf), keep_idxs, 0))
#     376 setattr(layer, 'weight_hh_l0'+pf, self._prune_parameter_and_grad(
#     377     getattr(layer, 'weight_hh_l0'+pf), keep_idxs, 0))
# --> 378 setattr(layer, 'weight_ih_l0'+pf,  self._prune_parameter_and_grad(
#     379     getattr(layer, 'weight_ih_l0'+pf), expanded_keep_idxs, 1))
#     380 if layer.bias:
#     381     setattr(layer, 'bias_ih_l0'+pf, self._prune_parameter_and_grad(
#     382         getattr(layer, 'bias_ih_l0'+pf), keep_idxs, 0))
#
# File ~/.virtualenvs/master-thesis/lib/python3.12/site-packages/torch_pruning/pruner/function.py:107, in BasePruningFunc._prune_parameter_and_grad(self, weight, keep_idxs, pruning_dim)
#     106 def _prune_parameter_and_grad(self, weight, keep_idxs, pruning_dim):
# --> 107     pruned_weight = torch.nn.Parameter(torch.index_select(weight, pruning_dim, torch.LongTensor(keep_idxs).to(weight.device).contiguous()))
#     108     if weight.grad is not None:
#     109         pruned_weight.grad = torch.index_select(weight.grad, pruning_dim, torch.LongTensor(keep_idxs).to(weight.device))
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
